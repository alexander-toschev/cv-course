# %%
# !colmap feature_extractor --database_path 3dReconstruction/south-building/database2.db /
  --image_path 3dReconstruction/south-building/images
# Out:
#   Cell In[2], line 2
#     --image_path south-building/images
#     ^
# IndentationError: unexpected indent

# %%
# !colmap exhaustive_matcher  --database_path south-building/database.db
# Out:
# I20250521 19:31:26.106570 339150 misc.cc:198]
# ...
# Exhaustive feature matching
# ...
# I20250521 19:31:26.189842 339150 feature_matching.cc:231] Matching block [1/3, 1/3]
# I20250521 19:31:26.223063 339150 feature_matching.cc:46]  in 0.033s
# I20250521 19:31:26.223248 339150 feature_matching.cc:231] Matching block [1/3, 2/3]
# I20250521 19:31:26.266723 339150 feature_matching.cc:46]  in 0.044s
# I20250521 19:31:26.266939 339150 feature_matching.cc:231] Matching block [1/3, 3/3]
# I20250521 19:31:26.283941 339150 feature_matching.cc:46]  in 0.017s
# I20250521 19:31:26.284175 339150 feature_matching.cc:231] Matching block [2/3, 1/3]
# I20250521 19:31:26.334609 339150 feature_matching.cc:46]  in 0.050s
# I20250521 19:31:26.334805 339150 feature_matching.cc:231] Matching block [2/3, 2/3]
# I20250521 19:31:26.372473 339150 feature_matching.cc:46]  in 0.038s
# I20250521 19:31:26.372668 339150 feature_matching.cc:231] Matching block [2/3, 3/3]
# ...

# %%
# !mkdir sparse

# %%
# !colmap mapper \
  --database_path south-building/database.db \
  --image_path south-building/images \
  --output_path sparse
# Out:
# I20250521 19:31:33.375432 339167 misc.cc:198]
# ...
# Loading database
# ...
# I20250521 19:31:33.412401 339167 database_cache.cc:54] Loading cameras...
# I20250521 19:31:33.413707 339167 database_cache.cc:64]  1 in 0.001s
# I20250521 19:31:33.413753 339167 database_cache.cc:72] Loading matches...
# I20250521 19:31:33.668773 339167 database_cache.cc:78]  1887 in 0.255s
# I20250521 19:31:33.668836 339167 database_cache.cc:94] Loading images...
# I20250521 19:31:34.457957 339167 database_cache.cc:143]  128 in 0.789s (connected 128)
# I20250521 19:31:34.458041 339167 database_cache.cc:154] Building correspondence graph...
# I20250521 19:31:34.666118 339167 database_cache.cc:190]  in 0.208s (ignored 0)
# I20250521 19:31:34.666469 339167 timer.cc:91] Elapsed time: 0.021 [minutes]
# I20250521 19:31:34.689316 339167 misc.cc:198]
# ...
# Finding good initial image pair
# ...
# I20250521 19:31:34.930274 339167 misc.cc:198]
# ...
# Initializing with image pair #33 and #6
# ...
# I20250521 19:31:34.937147 339167 misc.cc:198]
# ...

# %%
# !colmap model_converter \
  --input_path sparse/0 \
  --output_path model.ply \
  --output_type PLY

# %%
# !pip install open3d
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 18.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 21.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 23.6 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [open3d]14/15 [open3d]ets]
# ...
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# RPly: Unable to open file
# [Open3D WARNING] Read PLY failed: unable to open file: sparse/0/points3D.ply
# [Open3D WARNING] The number of points is 0 when creating axis-aligned bounding box.
# ...

# %%
import open3d as o3d

pcd = o3d.io.read_point_cloud("model.ply")
o3d.visualization.draw_geometries([pcd])
